# %%
import pandas as pd
from IPython.display import display

# %%
df = pd.read_csv("../fetal_health.csv")
df
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# 4              132.0          0.007           0.000                 0.008
# ...              ...            ...             ...                   ...
# 2121           140.0          0.000           0.000                 0.007
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %% [markdown]
# **Normalizing data**

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

categorical_columns = list(df.dtypes[df.dtypes == 'object'].index)

for c in categorical_columns:
    df[c] = df[c].str.lower().str.replace(' ', '_')
df
# Out:
#       baseline_value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# 4              132.0          0.007           0.000                 0.008
# ...              ...            ...             ...                   ...
# 2121           140.0          0.000           0.000                 0.007
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %%
for column in df.columns:
    print(f"Value counts for column '{column}':")
    display(df[column].value_counts())
    print("\n")  # Add spacing between columns
# Out:
# Value counts for column 'baseline_value':
# baseline_value
# 133.0    136
# 130.0    111
# 122.0    109
# 138.0    103
# 125.0     91
# 128.0     85
# 120.0     78
# 142.0     77
# 144.0     77
# 132.0     76
# 136.0     72
# 140.0     70
# 134.0     67
# 135.0     65
# 146.0     62
# 127.0     60
# 137.0     59
# 129.0     57
# 131.0     56
# 143.0     56
# 123.0     56
# 148.0     52
# 121.0     44
# 139.0     39
# 141.0     39
# 126.0     38
# 145.0     37
# 115.0     28
# 150.0     26
# 110.0     21
# 149.0     18
# 119.0     17
# 152.0     17
# 112.0     16
# 147.0     14
# 151.0     14
# 159.0     12
# 114.0     11
# 158.0     10
# 124.0     10
# 118.0      9
# 154.0      8
# 106.0      7
# 116.0      5
# 157.0      4
# 156.0      4
# 117.0      2
# 160.0      1
# Name: count, dtype: int64
# Value counts for column 'accelerations':
# accelerations
# 0.000    894
# 0.003    161
# 0.002    160
# 0.001    143
# 0.004    117
# 0.006    112
# 0.005    110
# 0.008    103
# ...

# %%
fetal_health_values = {
    1: 'normal',
    2: 'suspect',
    0: 'pathological'
}

# Create a copy of the original DataFrame
temporary_df = df.copy()

# Map the 'fetal_health' values and assign to a new column 'status'
temporary_df['fetal_health_str'] = temporary_df['fetal_health'].map(fetal_health_values)

# Display the temporary DataFrame
del temporary_df['fetal_health']
temporary_df
# Out:
#       baseline_value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# 4              132.0          0.007           0.000                 0.008
# ...              ...            ...             ...                   ...
# 2121           140.0          0.000           0.000                 0.007
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %% [markdown]
# **Checking for missing values (no missing values found)**

# %%
df.isnull().sum()
# Out:
# baseline_value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %% [markdown]
# **This is an example workflow and has been abstracted to ```0. Transforming data.ipynb``` to save the unnecessary compute of the user.
# <br>
# Saving the DataFrame (turns out there was no need for cleaning the dataframe but <br>
# we will transform the target variable from float to int to make it easier on the model)**

# %%
#df.fetal_health = df.fetal_health.astype(int)

# %%
#
# Out:
# fetal_health
# 1    1655
# 2     295
# 3     176
# Name: count, dtype: int64

# %%
#df.to_csv('transformed_fetal_health.csv', index=False)
#df = pd.read_csv("../fetal_health.csv")
#df
# Out:
#       baseline_value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# 4              132.0          0.007           0.000                 0.008
# ...              ...            ...             ...                   ...
# 2121           140.0          0.000           0.000                 0.007
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %%
temporary_df.T
# Out:
#                                                        0       1       2     \
# baseline_value                                        120.0   132.0   133.0
# accelerations                                           0.0   0.006   0.003
# fetal_movement                                          0.0     0.0     0.0
# uterine_contractions                                    0.0   0.006   0.008
# light_decelerations                                     0.0   0.003   0.003
# severe_decelerations                                    0.0     0.0     0.0
# prolongued_decelerations                                0.0     0.0     0.0
# abnormal_short_term_variability                        73.0    17.0    16.0
# mean_value_of_short_term_variability                    0.5     2.1     2.1
# percentage_of_time_with_abnormal_long_term_vari...     43.0     0.0     0.0
# mean_value_of_long_term_variability                     2.4    10.4    13.4
# ...
